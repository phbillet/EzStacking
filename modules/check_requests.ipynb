# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
xls = pd.ExcelFile('./ezstacking_config.ods', engine="odf")
meta_package = pd.read_excel(xls, 'meta_package', keep_default_na=False)
package_source = pd.read_excel(xls, 'package_source', keep_default_na=False)
package = pd.read_excel(xls, 'package', keep_default_na=False)
document = pd.read_excel(xls, 'document', keep_default_na=False)

# %%
package_source_type = 'full'
data_size = 'large'
kaggle = True

# %%
pd_pk_import = package_source[(package_source.package_source_type   == package_source_type) &\
                              ((package_source.package_source_kaggle == 'both') | \
                               (package_source.package_source_kaggle == kaggle))\
                             ].merge(meta_package[(meta_package.meta_package_valid == True) & \
                                     ((meta_package.meta_package_data_size == 'both') | \
                                     (meta_package.meta_package_data_size == data_size))], \
                                     left_on  = 'meta_package_index', \
                                     right_on = 'meta_package_index', \
                                     how = 'inner') \
                             [['package_source_index', 'package_source_name', \
                               'package_source_short_name', 'package_source_code']]
pd_pk_import
# Out:
#    package_source_index package_source_name package_source_short_name  \
# 0                    NP               numpy                        np
# 1                    PD              pandas                        pd
# 2                   SNS             seaborn                       sns
# 3                    OS                  os                      None
# 4                    GC                  gc                      None
# 5                 MPLPL   matplotlib.pyplot                       plt
# 6                  WARN            warnings                      None
# 7                  CPUN                None                      None
# 8                    RE                  re                      None
# 9                  MATH                math                      None
# 10                 SKEV  sklearn_evaluation                      skev
# 11                  KER               keras                      None
#
#                           package_source_code
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# 5                                        None
# 6           warnings.filterwarnings('ignore')
# 7   os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
# 8                                        None
# 9                                        None
# 10                                       None
# 11                                       None

# %%
package_source_type = 'partial'
data_size = 'small'

# %%
pd_pk_srce_from = package_source[(package_source.package_source_type == package_source_type)\
                                ].merge(meta_package[(meta_package.meta_package_valid == True) & \
                                         ((meta_package.meta_package_data_size == 'both') | \
                                         (meta_package.meta_package_data_size == data_size))], \
                                        left_on  = 'meta_package_index', \
                                        right_on = 'meta_package_index', \
                                        how = 'inner') \
                                [['package_source_index', 'package_source_name', \
                                  'package_source_short_name', 'package_source_code']] 
pd_pk_srce_from
# Out:
#    package_source_index                     package_source_name  \
# 0                  PDAT                        pandas.api.types
# 1                   ITT                               itertools
# 2                    JL                                  joblib
# 3                  SCIP                                   scipy
# 4                   SKL                                 sklearn
# 5                  SKLB                            sklearn.base
# 6                  SKLC                         sklearn.compose
# 7                  SKLE                    sklearn.experimental
# 8                  SKLI                          sklearn.impute
# 9                 SKLGP                sklearn.gaussian_process
# 10               SKLGPK        sklearn.gaussian_process.kernels
# 11                 SKLT                            sklearn.tree
# 12                SKLEN                        sklearn.ensemble
# 13                SKLIN                      sklearn.inspection
# 14                SKLLM                    sklearn.linear_model
# 15                 SKLM                         sklearn.metrics
# 16                SKLMS                 sklearn.model_selection
# 17                SKLNN                  sklearn.neural_network
# 18                SKLNE                       sklearn.neighbors
# 19                SKLNB                     sklearn.naive_bayes
# 20                SKLPI                        sklearn.pipeline
# 21                SKLPR                   sklearn.preprocessing
# 22               SKLSVM                             sklearn.svm
# 23                  YBC                  yellowbrick.classifier
# 24                 YBCR           yellowbrick.classifier.rocauc
# 25                 YBCT        yellowbrick.classifier.threshold
# 26                 YBMS             yellowbrick.model_selection
# 27                  YBF                    yellowbrick.features
# 28                  YBR                   yellowbrick.regressor
# 29                 YBCM             yellowbrick.contrib.missing
# 30                  YBT                      yellowbrick.target
# 31                YBTFC  yellowbrick.target.feature_correlation
# 32                  YDP                         ydata_profiling
# 33                 FEDA                                 fasteda
# 34                   GB                        sklearn.ensemble
# 35                 KERL                            keras.layers
# 36                 KERM                            keras.models
# 37              KERWSKL                       scikeras.wrappers
# 38                KERCB                         keras.callbacks
#
#    package_source_short_name package_source_code
# 0                       None                None
# 1                       None                None
# 2                       None                None
# 3                       None                None
# 4                       None                None
# 5                       None                None
# 6                       None                None
# 7                       None                None
# 8                       None                None
# 9                       None                None
# 10                      None                None
# 11                      None                None
# 12                      None                None
# 13                      None                None
# 14                      None                None
# 15                      None                None
# 16                      None                None
# 17                      None                None
# 18                      None                None
# 19                      None                None
# 20                      None                None
# 21                      None                None
# 22                      None                None
# 23                      None                None
# 24                      None                None
# 25                      None                None
# 26                      None                None
# 27                      None                None
# 28                      None                None
# 29                      None                None
# 30                      None                None
# 31                      None                None
# 32                      None                None
# 33                      None                None
# 34                      None                None
# 35                      None                None
# 36                      None                None
# 37                      None                None
# 38                      None                None

# %%
problem = 'regression'

# %%
pd_pk_from = package[((package.package_problem == 'None') | (package.package_problem == problem)) \
                    ].merge(pd_pk_srce_from, \
                            left_on='package_source_index', \
                            right_on='package_source_index',\
                            how='inner') \
                     .merge(meta_package[(meta_package.meta_package_valid == True) & \
                                         ((meta_package.meta_package_data_size == 'both') | \
                                         (meta_package.meta_package_data_size == data_size))], \
                            left_on  = 'meta_package_index', \
                            right_on = 'meta_package_index', \
                            how = 'inner') \
                [['package_source_index', 'package_source_name', 'package_name']].drop_duplicates()
pd_pk_from
# Out:
#    package_source_index                     package_source_name  \
# 0                 SKLLM                    sklearn.linear_model
# 1                  SKLB                            sklearn.base
# 2                 KERCB                         keras.callbacks
# 3                 KERCB                         keras.callbacks
# 4                 SKLGP                sklearn.gaussian_process
# 7                  SKLT                            sklearn.tree
# 10                SKLEN                        sklearn.ensemble
# 13                SKLEN                        sklearn.ensemble
# 14                SKLEN                        sklearn.ensemble
# 19                SKLEN                        sklearn.ensemble
# 20                SKLEN                        sklearn.ensemble
# 21                SKLLM                    sklearn.linear_model
# 23                SKLLM                    sklearn.linear_model
# 24                SKLLM                    sklearn.linear_model
# 25                SKLLM                    sklearn.linear_model
# 26                SKLLM                    sklearn.linear_model
# 27                SKLNN                  sklearn.neural_network
# 29                SKLNE                       sklearn.neighbors
# 31               SKLSVM                             sklearn.svm
# 34                   GB                        sklearn.ensemble
# 35              KERWSKL                       scikeras.wrappers
# 36                 SKLE                    sklearn.experimental
# 37                 SKLI                          sklearn.impute
# 38                 SKLI                          sklearn.impute
# 39                SKLIN                      sklearn.inspection
# 40               SKLGPK        sklearn.gaussian_process.kernels
# 41               SKLGPK        sklearn.gaussian_process.kernels
# 42               SKLGPK        sklearn.gaussian_process.kernels
# 43               SKLGPK        sklearn.gaussian_process.kernels
# 44               SKLGPK        sklearn.gaussian_process.kernels
# 45               SKLGPK        sklearn.gaussian_process.kernels
# 46               SKLGPK        sklearn.gaussian_process.kernels
# 47                 KERL                            keras.layers
# 48                 KERL                            keras.layers
# 49                 KERL                            keras.layers
# 50                 KERL                            keras.layers
# 51                 KERM                            keras.models
# 52                 SKLM                         sklearn.metrics
# 53                 SKLM                         sklearn.metrics
# 54                 PDAT                        pandas.api.types
# 55                  ITT                               itertools
# 56                   JL                                  joblib
# 57                 SCIP                                   scipy
# 58                  SKL                                 sklearn
# 59                  SKL                                 sklearn
# 60                SKLMS                 sklearn.model_selection
# 61                SKLMS                 sklearn.model_selection
# 62                SKLMS                 sklearn.model_selection
# 63                SKLNE                       sklearn.neighbors
# 64                SKLPI                        sklearn.pipeline
# 65                SKLPI                        sklearn.pipeline
# 66                 SKLB                            sklearn.base
# 67                 SKLC                         sklearn.compose
# 68                SKLPR                   sklearn.preprocessing
# 69                SKLPR                   sklearn.preprocessing
# 70                SKLPR                   sklearn.preprocessing
# 71                SKLPR                   sklearn.preprocessing
# 72                SKLPR                   sklearn.preprocessing
# 73                 YBMS             yellowbrick.model_selection
# 74                 YBMS             yellowbrick.model_selection
# 75                  YBF                    yellowbrick.features
# 76                  YBF                    yellowbrick.features
# 77                 YBCM             yellowbrick.contrib.missing
# 78                 YBCM             yellowbrick.contrib.missing
# 79                YBTFC  yellowbrick.target.feature_correlation
# 80                  YBR                   yellowbrick.regressor
# 81                  YBR                   yellowbrick.regressor
# 82                  YDP                         ydata_profiling
# 83                 FEDA                                 fasteda
#
#                      package_name
# 0                 RidgeClassifier
# 1                   BaseEstimator
# 2                   EarlyStopping
# 3               ReduceLROnPlateau
# 4        GaussianProcessRegressor
# 7           DecisionTreeRegressor
# 10          RandomForestRegressor
# 13              AdaBoostRegressor
# 14               BaggingRegressor
# 19  HistGradientBoostingRegressor
# 20              StackingRegressor
# 21                   SGDRegressor
# 23                     ElasticNet
# 24               LinearRegression
# 25                          Ridge
# 26                   ElasticNetCV
# 27                   MLPRegressor
# 29            KNeighborsRegressor
# 31                            SVR
# 34      GradientBoostingRegressor
# 35                 KerasRegressor
# 36       enable_iterative_imputer
# 37                  SimpleImputer
# 38               IterativeImputer
# 39         permutation_importance
# 40                            RBF
# 41                    WhiteKernel
# 42                 ConstantKernel
# 43                         Matern
# 44              RationalQuadratic
# 45                 ExpSineSquared
# 46                     DotProduct
# 47                          Dense
# 48             BatchNormalization
# 49             LayerNormalization
# 50                        Dropout
# 51                     Sequential
# 52             mean_squared_error
# 53                       r2_score
# 54               is_numeric_dtype
# 55                        product
# 56                           dump
# 57                          stats
# 58                     set_config
# 59                       datasets
# 60               train_test_split
# 61                StratifiedKFold
# 62        RepeatedStratifiedKFold
# 63             LocalOutlierFactor
# 64                       Pipeline
# 65                  make_pipeline
# 66               TransformerMixin
# 67        make_column_transformer
# 68                 StandardScaler
# 69                  OneHotEncoder
# 70                 OrdinalEncoder
# 71                   LabelEncoder
# 72            FunctionTransformer
# 73                 learning_curve
# 74            feature_importances
# 75                         rank1d
# 76                         rank2d
# 77               MissingValuesBar
# 78        MissingValuesDispersion
# 79            feature_correlation
# 80               prediction_error
# 81                 residuals_plot
# 82                  ProfileReport
# 83                       fast_eda

# %%
pd_level_0 = package[(package.package_type == 'estimator') & \
                     (package.package_problem == problem) & \
                     (package.meta_package_index != 'STACK') \
                    ].merge(pd_pk_from, \
                            left_on='package_source_index', \
                            right_on='package_source_index',\
                            how='inner') \
                     .merge(meta_package[(meta_package.meta_package_valid == True) & \
                                         ((meta_package.meta_package_data_size == 'both') | \
                                         (meta_package.meta_package_data_size == data_size))], \
                            left_on  = 'meta_package_index', \
                            right_on = 'meta_package_index', \
                            how = 'inner') \
                    [[ 'package_index', 'package_code', 'meta_package_tree']].drop_duplicates()
pd_level_0
# Out:
#    package_index                                       package_code  \
# 0           GPRL  GaussianProcessRegressor(kernel = ConstantKern...
# 1           GPRR  GaussianProcessRegressor(kernel = ConstantKern...
# 2           GPRQ  GaussianProcessRegressor(kernel = ConstantKern...
# 3           DTRF  DecisionTreeRegressor(criterion='friedman_mse'...
# 4           DTRA  DecisionTreeRegressor(criterion='absolute_erro...
# 5           RFRS  RandomForestRegressor(criterion='squared_error...
# 10          RFRA  RandomForestRegressor(criterion='absolute_erro...
# 15           ABR     AdaBoostRegressor(random_state = random_state)
# 20          BAGR  BaggingRegressor(n_estimators=100, random_stat...
# 25        BAGRML  BaggingRegressor(estimator=MLPRegressor(), n_e...
# 30       BAGRSVL  BaggingRegressor(estimator=SVR(kernel='linear'...
# 35       BAGRSVP  BaggingRegressor(estimator=SVR(kernel='poly'),...
# 40       BAGRSVR  BaggingRegressor(estimator=SVR(kernel='rbf'), ...
# 45          HGBR  HistGradientBoostingRegressor(early_stopping=T...
# 50         SGDRS  SGDRegressor(loss='squared_error', penalty='el...
# 56         SGDRH  SGDRegressor(loss='huber', penalty='elasticnet...
# 62          ELNE  ElasticNet(alpha=0.01, l1_ratio=0.15, random_s...
# 68          LINR                                 LinearRegression()
# 74        ELNECV    ElasticNetCV(cv=5, random_state = random_state)
# 80         MLPR1  MLPRegressor(hidden_layer_sizes = (layer_size,...
# 81         MLPR2  MLPRegressor(hidden_layer_sizes = (layer_size,...
# 82          KNRU             KNeighborsRegressor(weights='uniform')
# 84          KNRD            KNeighborsRegressor(weights='distance')
# 86          SVRL                               SVR(kernel='linear')
# 87          SVRP                                 SVR(kernel='poly')
# 88          SVRG                                  SVR(kernel='rbf')
# 89           GBR  GradientBoostingRegressor(n_estimators=100, le...
# 90          KERR                                                K_R
#
#    meta_package_tree
# 0              False
# 1              False
# 2              False
# 3               True
# 4               True
# 5               True
# 10              True
# 15              True
# 20             False
# 25             False
# 30             False
# 35             False
# 40             False
# 45              True
# 50             False
# 56             False
# 62             False
# 68             False
# 74             False
# 80             False
# 81             False
# 82             False
# 84             False
# 86             False
# 87             False
# 88             False
# 89              True
# 90             False

# %%
pd_tree = package[(package.package_type == 'estimator') & \
                  (package.package_problem == problem) & \
                  (package.meta_package_index != 'STACK') \
                 ].merge(pd_pk_from, \
                         left_on='package_source_index', \
                         right_on='package_source_index',\
                         how='inner') \
                  .merge(meta_package[(meta_package.meta_package_tree == True) & \
                                      (meta_package.meta_package_valid == True) & \
                                      ((meta_package.meta_package_data_size == 'both') | \
                                      (meta_package.meta_package_data_size == data_size))], \
                         left_on  = 'meta_package_index', \
                         right_on = 'meta_package_index', \
                         how = 'inner') \
                  [[ 'package_index', 'package_code']].drop_duplicates()
pd_tree
# Out:
#    package_index                                       package_code
# 0           DTRF  DecisionTreeRegressor(criterion='friedman_mse'...
# 1           DTRA  DecisionTreeRegressor(criterion='absolute_erro...
# 2           RFRS  RandomForestRegressor(criterion='squared_error...
# 7           RFRA  RandomForestRegressor(criterion='absolute_erro...
# 12           ABR     AdaBoostRegressor(random_state = random_state)
# 17          HGBR  HistGradientBoostingRegressor(early_stopping=T...
# 22           GBR  GradientBoostingRegressor(n_estimators=100, le...

# %%
pd_document = document[((document.document_problem == 'both') | (document.document_problem == problem)) & \
                       ((document.document_data_size == 'both') | (document.document_data_size == data_size)) & \
                       ((document.document_stacking == 'both') | \
                       (document.document_stacking == \
                        meta_package[meta_package.meta_package_index == 'STACK']\
                        ['meta_package_valid'].tolist()[0]\
                       )) & \
                       ((document.document_keras == 'both') | \
                       (document.document_keras == \
                        meta_package[meta_package.meta_package_index == 'KER']\
                        ['meta_package_valid'].tolist()[0]\
                       )) & \
                       ((document.document_pipeline == 'both') | \
                       (document.document_pipeline == \
                        meta_package[meta_package.meta_package_index == 'PIP']\
                        ['meta_package_valid'].tolist()[0]\
                       )) & \
                       ((document.document_yb == 'both') | \
                       (document.document_yb == \
                        meta_package[meta_package.meta_package_index == 'YB']\
                        ['meta_package_valid'].tolist()[0]\
                       )) \
                      ].merge(meta_package[meta_package.meta_package_valid == True], \
                                           left_on  = 'meta_package_index', \
                                           right_on = 'meta_package_index', \
                                           how = 'inner') \
                      [['sort_key', 'title', 'text', 'code']].sort_values('sort_key') \
                      [['title', 'text', 'code']].drop_duplicates()

pd_document
# Out:
#      title                                               text  \
# 0        #                               Technical Parameters
# 1      ###                                       Project name
# 2      ###                      Thresholds & other parameters
# 3                                                        None
# 4                                                        None
# 5                                                        None
# 6                                                        None
# 7                                                        None
# 8                                                        None
# 9                                                        None
# 10                                                       None
# 11                                                       None
# 12                                                       None
# 13                                                       None
# 14                                                       None
# 15                                                       None
# 16                                                       None
# 17                                                       None
# 18                                                       None
# 19                                                       None
# 20                                                       None
# 21                                                       None
# 22     ###                                      File & target
# 23                                                       None
# 24                                                       None
# 25                                                       None
# 26     ###                                         Deployment
# 27                                                       None
# 28       #                    Exploratory Data Analysis (EDA)
# 29      ##                   Drop user's columns & Duplicates
# 30                                    Dataset before deletion
# 31                                                       None
# 32                                                       None
# 33                                            Duplicate rows:
# 34              Drop all the rows for which the target is NaN
# 35          Dataset after deletion of user’s columns and d...
# 36     ###                                       Dataset copy
# 37      ##                                Dataset Information
# 38     ###                                Dataframe structure
# 39     ###                               Dataframe statistics
# 40      ##                      Correlation & Autocorellation
# 41                                                       None
# 42      ##                             Seasonal decomposition
# 43     ###             Seasonal decomposition with one period
# 44     ###            Seasonal decomposition with two periods
# 45     ###                Unobserved components decomposition
# 46      ##               Which columns could be categorical ?
# 47      ##                                   Dataset Cleaning
# 48     ###                                          Drop NaN:
# 49                                Set of dropped columns: NaN
# 50                                                       None
# 51     ###                                     Encoding data:
# 52     ###                Imputing NaN using IterativeImputer
# 53                                                       None
# 54    ####                                         Imputation
# 55     ###                                  Data compression:
# 56    ####              Dataframe structure after compression
# 57     ###                                          Outliers:
# 58      ##                                          Plottings
# 60     ###                                           Ranking
# 61    ####                                        Ranking 1D
# 62    ####                                        Ranking 2D
# 64    ####                                        Ranking 1D
# 65    ####                                        Ranking 2D
# 66   #####                    Ranking 2D according to Pearson
# 67   #####                     Ranking 2D based on covariance
# 68   #####                   Ranking 2D according to Spearman
# 69   #####                 Ranking 2D according to Kendalltau
# 70     ###                   Correlation according to Pearson
# 71                                                       None
# 72   #####               Check columns that should be dropped
# 73     ###  Correlation according to Spearman (hierarchica...
# 74     ###                     Correlation with Yellow Bricks
# 75   #####        Splitting dataframe in features and targets
# 76                                                       None
# 77                                                       None
# 78                                                       None
# 79     ###                           Correlation with Seaborn
# 80    ####                               Heatmap with Seaborn
# 81     ###                           EDA with Ydata profiling
# 82                                                       None
# 83                                                       None
# 84                                                       None
# 85     ###                                  EDA with Fast EDA
# 86       #  Convert time series to supervised learning pro...
# 87                                                       None
# 88     ###                                         Quick EDA
# 89                                                       None
# 90       #                                          Splitting
# 91                                                       None
# 92      ##        Splitting dataframe in features and targets
# 93                                                       None
# 94                                                       None
# 95                                                       None
# 96                                                       None
# 97     ###                                         Dimensions
# 98                                                       None
# 99                                                       None
# 100    ###             Splitting data in train and test sets
# 101    ###             Splitting data in train and test sets
# 102      #                          Modeling: Model selection
# 103     ##                                     Model building
# 104    ###                                  Pipeline building
# 105   ####       Select the categorical and numerical columns
# 106   ####                           For models based on tree
# 107                                                      None
# 108                                                      None
# 109                                                      None
# 110   ####                       For models not based on tree
# 111                                                      None
# 112                                                      None
# 113                                                      None
# 114   ####                    Keras neural network definition
# 115  #####                                     Early Stopping
# 116  #####                               Reduce LR on plateau
# 117                                                      None
# 118   ####                                     Level-0 models
# 119   ####                                      Level-1 model
# 120   ####                                      Level-1 model
# 121   ####                                      Level-1 model
# 122   ####                            Stacking for regression
# 123     ##                                      Model fitting
# 124     ##                                   Model evaluation
# 125    ###                                      Model scoring
# 126    ###                                     Residuals plot
# 127    ###                                   Prediction error
# 128    ###                                         MAPE score
# 129    ###                             Time series evaluation
# 130     ##                                   Model inspection
# 131    ###                                   Model importance
# 132    ###                     Feature permutation importance
# 133    ###  Partial Dependence & Individual Conditional Ex...
# 134      #                        Modeling: Feature selection
# 135   ####                            Filtered Level-0 models
# 136   ####                               Build filtered model
# 137     ##                             Filtered Model fitting
# 138     ##                          Filtered Model evaluation
# 139    ###                             Filtered Model scoring
# 140    ###                                Filtered mape score
# 141    ###                    Filtered Time series evaluation
# 142    ###                            Filtered Residuals plot
# 143    ###                          Filtered Prediction error
# 144     ##                          Filtered Model inspection
# 145    ###                          Filtered Model importance
# 146    ###            Filtered feature permutation importance
# 147   ####                       Filtered feature elimination
# 148                                                      None
# 149   ####        Check those columns, they should be dropped
# 150      #                              Modeling: Final model
# 151                                                      None
# 152                                                      None
# 153                                                      None
# 154                                                      None
# 155                                                      None
# 157     ##                                         Quick EDA
# 158     ##                                          Splitting
# 159    ###        Splitting dataframe in features and targets
# 160                                                      None
# 161                                                      None
# 162                                                      None
# 163                                                      None
# 164    ###                                         Dimensions
# 165                                                      None
# 166                                                      None
# 167    ###             Splitting data in train and test sets
# 168    ###             Splitting data in train and test sets
# 169     ##                               Final model building
# 170   ####       Select the categorical and numerical columns
# 171   ####                           For models based on tree
# 172                                                      None
# 173                                                      None
# 174                                                      None
# 175   ####                       For models not based on tree
# 176                                                      None
# 177                                                      None
# 178                                                      None
# 179   ####                               Final level-0 models
# 180                                                      None
# 181   ####                              Build the final model
# 182     ##                                Final Model fitting
# 183     ##                             Final Model evaluation
# 184    ###                                Final Model scoring
# 185    ###               Final feature permutation importance
# 186    ###                          Final feature elimination
# 189    ###                               Final Residuals plot
# 190    ###                             Final Prediction error
# 191    ###                                   Final MAPE score
# 192    ###                       Final Time series evaluation
# 193     ##                             Final Model inspection
# 194    ###                             Final Model importance
# 195    ###               Final Feature permutation importance
# 196    ###  Final Partial Dependence & Individual Conditio...
# 197      #                                  Test & Deployment
# 198    ###                                     Save the model
# 199    ###                                Generate the server
# 200    ###                     [Test the API](./server.ipynb)
#
#                                                   code
# 0                                                 None
# 1                 "name = '" + str(project_name) + "'"
# 2         "problem_type = '" + str(problem_type) + "'"
# 3               "data_size = '" + str(data_size) + "'"
# 4              "threshold_NaN = " + str(threshold_NaN)
# 5             "threshold_cat = " + str(threshold_cat)
# 6                  "threshold_Z = " + str(threshold_Z)
# 7                      "test_size = " + str(test_size)
# 8      "threshold_entropy = " + str(threshold_entropy)
# 9              "undersampling = " + str(undersampling)
# 10        "undersampler = '" + str(undersampler) + "'"
# 11           "threshold_corr = " + str(threshold_corr)
# 12         "threshold_model = " + str(threshold_model)
# 13         "threshold_score = " + str(threshold_score)
# 14     "threshold_feature = " + str(threshold_feature)
# 15                   "with_keras = " + str(with_keras)
# 16                            "CPU = " + str(with_CPU)
# 17                       "time_dep = " + str(time_dep)
# 18                       "date_idx = " + str(date_idx)
# 19                   "lag_number = " + str(lag_number)
# 20      "level_1_model = '" + str(level_1_model) + "'"
# 21               "random_state = " + str(random_state)
# 22                        "path = '" + str(file) + "'"
# 23                            "df = pd.read_csv(path)"
# 24   "df = pd.read_csv(path, index_col = date_idx, ...
# 25            "target_col = '" + str(target_col) + "'"
# 26    "FastAPI_port = " + str(deployment_FastAPI_port)
# 27      "Docker_port = " + str(deployment_Docker_port)
# 28                                                None
# 29           "user_drop_cols = " + str(user_drop_cols)
# 30                                       "display(df)"
# 31              "df = df.drop(user_drop_cols, axis=1)"
# 32                     "dropped_cols = user_drop_cols"
# 33                               "df = duplicates(df)"
# 34               "df = df.dropna(subset=[target_col])"
# 35                                       "display(df)"
# 36                               "df_copy = df.copy()"
# 37                                                None
# 38                      "plot_dataframe_structure(df)"
# 39                          "display(df.describe().T)"
# 40             "plot_correlation(df, target_col, t=1)"
# 41    "plot_acf_pacf(df, column=df.columns.to_list())"
# 42                                                None
# 43   "plot_seasonal_decompose(df, column=df.columns...
# 44   "plot_seasonal_decompose_2(df, column=df.colum...
# 45   "plot_unobserved_components(df, column=df.colu...
# 46                              "plot_categorical(df)"
# 47                                                None
# 48   "df, drop_cols = drop_na(df, target_col, thres...
# 49   "dropped_cols = np.unique(np.concatenate((drop...
# 50                             "display(dropped_cols)"
# 51   "df, encoded_cols = encoding(df, threshold_cat...
# 52                                                None
# 53   "visualizer = MissingValuesBar(features=df.sel...
# 54                               "df = imputation(df)"
# 55                          "df = downcast_dtypes(df)"
# 56                      "plot_dataframe_structure(df)"
# 57                    "df = outliers(df, threshold_Z)"
# 58                                                None
# 60                                                None
# 61   "rank1d = skev.plot.Rank1D() \nrank1d.feature_...
# 62   "rank2d = skev.plot.Rank2D() \nrank2d.feature_...
# 64                                       "rank1d(df);"
# 65                                                None
# 66                  "rank2d(df, algorithm='pearson');"
# 67               "rank2d(df, algorithm='covariance');"
# 68                 "rank2d(df, algorithm='spearman');"
# 69               "rank2d(df, algorithm='kendalltau');"
# 70   "corr = df.corr() \ncorr.style.background_grad...
# 71   "correlated_features = correlated_columns(df, ...
# 72                               "print(dropped_cols)"
# 73   "selected_features_names = hierarchical_cluste...
# 74                                                None
# 75                                "y = df[target_col]"
# 76                   "X = df.drop(target_col, axis=1)"
# 77                        "feature_correlation(X, y);"
# 78   "feature_correlation(X, y, method='mutual_info...
# 79               "plot_sns_corr_regre(df, target_col)"
# 80   "plt.figure()\nsns.heatmap(df.corr())\nplt.sho...
# 81                                                None
# 82     "profile = ProfileReport(df_copy, tsmode=True)"
# 83   "profile = ProfileReport(df_copy, explorative=...
# 84                      "profile.to_notebook_iframe()"
# 85                                      "fast_eda(df)"
# 86                               "df_copy = df.copy()"
# 87   "df_s, target_col_ts, preds = ts_dataframe_to_...
# 88        "plot_correlation(df_s, target_col_ts, t=1)"
# 89     "encoding(df_s, threshold_cat, target_col_ts);"
# 90                                                None
# 91                                      "df = df_copy"
# 92                                                None
# 93                                "y = df[target_col]"
# 94                   "X = df.drop(target_col, axis=1)"
# 95                           "y = df_s[target_col_ts]"
# 96              "X = df_s.drop(target_col_ts, axis=1)"
# 97             "nb_features = len(X.columns.tolist())"
# 98                                    "nb_targets = 1"
# 99         "layer_size = nb_features + nb_targets + 2"
# 100  "X_train, X_test, y_train, y_test = split(X, y...
# 101  "X_train, X_test, y_train, y_test = timeseries...
# 102                                               None
# 103                                               None
# 104                                               None
# 105      "cat_selector, num_selector = get_features()"
# 106  "cat_tree_processor = make_pipeline(SimpleImpu...
# 107  "num_tree_processor = make_pipeline(IterativeI...
# 108  "tree_preprocessor = make_pipeline(make_column...
# 109  "tree_preprocessor = make_column_transformer((...
# 110  "cat_ntree_processor = make_pipeline(SimpleImp...
# 111  "num_ntree_processor = make_pipeline(Iterative...
# 112  "ntree_preprocessor = make_pipeline(make_colum...
# 113  "ntree_preprocessor = make_column_transformer(...
# 114                             keras_nn(problem_type)
# 115  "es = EarlyStopping(monitor='val_loss', mode='...
# 116  "reduce_lr = ReduceLROnPlateau(monitor='val_lo...
# 117  "K_R = K_MLPRegressor(hidden_layer_sizes=50, a...
# 118                           pipe_level_0(pd_level_0)
# 119  "level_1 = Ridge(alpha=1, positive=True, rando...
# 120  "level_1 = Ridge(alpha=1, positive=False, rand...
# 121  "level_1 = DecisionTreeRegressor(random_state ...
# 122  "model = StackingRegressor(level_0, final_esti...
# 123  "%%time \nset_config(display='diagram') \nmode...
# 124                                               None
# 125  "score_stack_0, mod_imp_score_0 = score_stacki...
# 126  "residuals_plot(model, X_train, y_train, X_tes...
# 127  "prediction_error(model, X_train, y_train, X_t...
# 128   "K_mape(model,X_train, y_train, X_test, y_test)"
# 129  "plot_ts_results(X_train, y_train, X_test, y_t...
# 130                                               None
# 131  "model_imp_0 = plot_model_importance(model, le...
# 132  "feature_importance_0 = plot_perm_importance(m...
# 133  "pd_ice_plot(model=model, X=X_test, feature=X_...
# 134                                               None
# 135  "level_0_f = model_filtering(level_0, model_im...
# 136  "model = StackingRegressor(level_0_f, final_es...
# 137  "%%time \nset_config(display='diagram') \nmode...
# 138                                               None
# 139  "score_stack_1, mod_imp_score_1 = score_stacki...
# 140   "K_mape(model,X_train, y_train, X_test, y_test)"
# 141  "plot_ts_results(X_train, y_train, X_test, y_t...
# 142  "residuals_plot(model, X_train, y_train, X_tes...
# 143  "prediction_error(model, X_train, y_train, X_t...
# 144                                               None
# 145  "model_imp_1 = plot_model_importance(model, le...
# 146  "feature_importance_1 = plot_perm_importance(m...
# 147  "best_feature, worst_feature = feature_filteri...
# 148  "dropped_cols = np.unique(np.concatenate((drop...
# 149                              "print(dropped_cols)"
# 150                                               None
# 151                             "df_copy = df.copy() "
# 152  "df = df_copy.drop(dropped_cols, axis=1, error...
# 153       "reduce_schema('column_name', dropped_cols)"
# 154  "df_s, target_col_ts, preds = ts_dataframe_to_...
# 155  "df_s = df_s.drop(dropped_cols, axis=1, errors...
# 157      "plot_correlation(df_s, target_col_ts, t=1) "
# 158                                               None
# 159                                               None
# 160                              "y = df[target_col] "
# 161                 "X = df.drop(target_col, axis=1) "
# 162                         "y = df_s[target_col_ts] "
# 163            "X = df_s.drop(target_col_ts, axis=1) "
# 164           "nb_features = len(X.columns.tolist()) "
# 165                                  "nb_targets = 1 "
# 166       "layer_size = nb_features + nb_targets + 2 "
# 167  "X_train, X_test, y_train, y_test = split(X, y...
# 168  "X_train, X_test, y_train, y_test = timeseries...
# 169                                               None
# 170     "cat_selector, num_selector = get_features() "
# 171  "cat_tree_processor = make_pipeline(SimpleImpu...
# 172  "num_tree_processor = make_pipeline(IterativeI...
# 173  "tree_preprocessor = make_pipeline(make_column...
# 174  "tree_preprocessor = make_column_transformer((...
# 175  "cat_ntree_processor = make_pipeline(SimpleImp...
# 176  "num_ntree_processor = make_pipeline(Iterative...
# 177  "ntree_preprocessor = make_pipeline(make_colum...
# 178  "ntree_preprocessor = make_column_transformer(...
# 179                           pipe_level_0(pd_level_0)
# 180  "level_0_f = list(set(level_0) & set(model_fil...
# 181  "model = StackingRegressor(level_0_f, final_es...
# 182  "%%time \nset_config(display='diagram') \nmode...
# 183                                               None
# 184  "score_stack_2, mod_imp_score_2 = score_stacki...
# 185  "feature_importance_2 = feature_importance = p...
# 186  "best_feature, worst_feature = feature_filteri...
# 189  "residuals_plot(model, X_train, y_train, X_tes...
# 190  "prediction_error(model, X_train, y_train, X_t...
# 191   "K_mape(model,X_train, y_train, X_test, y_test)"
# 192  "plot_ts_results(X_train, y_train, X_test, y_t...
# 193                                               None
# 194  "model_imp_2 = plot_model_importance(model, le...
# 195  "plot_perm_importance(model, X_test, y_test, C...
# 196  "pd_ice_plot(model=model, X=X_test, feature=X_...
# 197                                               None
# 198  "model_name = 'model.sav' \ndump(model, model_...
# 199  "fastapi_server(model, 'model.sav', X, y, Fast...
# 200                                               None
