# %% [markdown]
# # FastAPI Endpoint Server

# %% [markdown]
# ### Start the server

# %%
run server.py

# %% [markdown]
# ### Test your API at http://127.0.0.1:8000/docs or with [client](./client.ipynb)
