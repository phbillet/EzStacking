# %% [markdown]
# # EDA & Modelling

# %% [markdown]
# ## Package loading

# %%
from EZS_func import *
import numpy as np
import pandas as pd
import os
import gc
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import re
import math
import keras
from sklearn.base import BaseEstimator
from sklearn.base import TransformerMixin
from keras.callbacks import EarlyStopping
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from xgboost import plot_tree
from xgboost import to_graphviz
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer
from sklearn.impute import IterativeImputer
from sklearn.inspection import permutation_importance
from sklearn.gaussian_process.kernels import RBF
from sklearn.gaussian_process.kernels import WhiteKernel
from sklearn.gaussian_process.kernels import ConstantKernel
from sklearn.gaussian_process.kernels import Matern
from sklearn.gaussian_process.kernels import RationalQuadratic
from sklearn.gaussian_process.kernels import ExpSineSquared
from sklearn.gaussian_process.kernels import DotProduct
from keras.layers import Dense
from keras.layers import BatchNormalization
from keras.layers import LayerNormalization
from keras.models import Sequential
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from pandas.api.types import is_numeric_dtype
from itertools import product
from scipy import stats
from sklearn import set_config
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from keras.utils import np_utils
from sklearn.compose import make_column_selector
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import FunctionTransformer
from yellowbrick.model_selection import learning_curve
from yellowbrick.model_selection import feature_importances
from yellowbrick.features import rank1d
from yellowbrick.features import rank2d
from yellowbrick.contrib.missing import MissingValuesBar
from yellowbrick.contrib.missing import MissingValuesDispersion
from yellowbrick.target.feature_correlation import feature_correlation
from yellowbrick.regressor import prediction_error
from yellowbrick.regressor import residuals_plot
from keras.utils.vis_utils import plot_model

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### File and parameters loading

# %%
problem_type = 'regression'

# %%
stacking = 'True'

# %%
data_size = 'large'

# %%
df = pd.read_csv('/home/philippe/Documents/python project/EZStacking-v0.11/dataset/superconductors.csv')

# %%
target_col = 'critical_temp'

# %%
user_drop_cols = []

# %%
threshold_NaN = 0.5

# %%
threshold_cat = 5

# %%
threshold_Z = 3.0

# %% [markdown]
# #### Dataset copy

# %%
df_copy = df.copy()

# %% [markdown]
# ### Dataset Information

# %%
df.shape
# Out:
# (21263, 82)

# %% [markdown]
# #### Some records

# %%
display(df)
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                       4         88.944468             57.862692
# 1                       5         92.729214             58.518416
# 2                       4         88.944468             57.885242
# 3                       4         88.944468             57.873967
# 4                       4         88.944468             57.840143
# ...                   ...               ...                   ...
# 21258                   4        106.957877             53.095769
# 21259                   5         92.266740             49.021367
# 21260                   2         99.663190             95.609104
# 21261                   2         99.663190             97.095602
# 21262                   3         87.468333             86.858500
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0              66.361592              36.116612             1.181795
# 1              73.132787              36.396602             1.449309
# 2              66.361592              36.122509             1.181795
# 3              66.361592              36.119560             1.181795
# 4              66.361592              36.110716             1.181795
# ...                  ...                    ...                  ...
# 21258          82.515384              43.135565             1.177145
# 21259          64.812662              32.867748             1.323287
# 21260          99.433882              95.464320             0.690847
# 21261          99.433882              96.901083             0.690847
# 21262          82.555758              80.458722             1.041270
#
#        wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                     1.062396          122.90607              31.794921
# 1                     1.057755          122.90607              36.161939
# 2                     0.975980          122.90607              35.741099
# 3                     1.022291          122.90607              33.768010
# 4                     1.129224          122.90607              27.848743
# ...                        ...                ...                    ...
# 21258                 1.254119          146.88130              15.504479
# 21259                 1.571630          188.38390               7.353333
# 21260                 0.530198           13.51362              53.041104
# 21261                 0.640883           13.51362              31.115202
# 21262                 0.895229           71.75500              43.144000
#
#        std_atomic_mass  ...  wtd_mean_Valence  gmean_Valence  \
# 0            51.968828  ...          2.257143       2.213364
# 1            47.094633  ...          2.257143       1.888175
# 2            51.968828  ...          2.271429       2.213364
# 3            51.968828  ...          2.264286       2.213364
# 4            51.968828  ...          2.242857       2.213364
# ...                ...  ...               ...            ...
# 21258        65.764081  ...          3.555556       3.223710
# 21259        69.232655  ...          2.047619       2.168944
# 21260         6.756810  ...          4.800000       4.472136
# 21261         6.756810  ...          4.690000       4.472136
# 21262        29.905282  ...          4.500000       4.762203
#
#        wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0               2.219783         1.368922             1.066221              1
# 1               2.210679         1.557113             1.047221              2
# 2               2.232679         1.368922             1.029175              1
# 3               2.226222         1.368922             1.048834              1
# 4               2.206963         1.368922             1.096052              1
# ...                  ...              ...                  ...            ...
# 21258           3.519911         1.377820             0.913658              1
# 21259           2.038991         1.594167             1.337246              1
# 21260           4.781762         0.686962             0.450561              1
# 21261           4.665819         0.686962             0.577601              1
# 21262           4.242641         1.054920             0.970116              3
#
#        wtd_range_Valence  std_Valence  wtd_std_Valence  critical_temp
# 0               1.085714     0.433013         0.437059          29.00
# 1               1.128571     0.632456         0.468606          26.00
# 2               1.114286     0.433013         0.444697          19.00
# 3               1.100000     0.433013         0.440952          22.00
# 4               1.057143     0.433013         0.428809          23.00
# ...                  ...          ...              ...            ...
# 21258           2.168889     0.433013         0.496904           2.44
# 21259           0.904762     0.400000         0.212959         122.10
# 21260           3.200000     0.500000         0.400000           1.98
# 21261           2.210000     0.500000         0.462493           1.84
# 21262           1.800000     1.414214         1.500000          12.80
#
# [21263 rows x 82 columns]

# %% [markdown]
# #### Dataframe structure

# %%
plot_dataframe_structure(df)

# %% [markdown]
# #### Dataframe statistics

# %%
display(df.describe().T)
# Out:
#                          count       mean        std       min        25%  \
# number_of_elements     21263.0   4.115224   1.439295  1.000000   3.000000
# mean_atomic_mass       21263.0  87.557631  29.676497  6.941000  72.458076
# wtd_mean_atomic_mass   21263.0  72.988310  33.490406  6.423452  52.143839
# gmean_atomic_mass      21263.0  71.290627  31.030272  5.320573  58.041225
# wtd_gmean_atomic_mass  21263.0  58.539916  36.651067  1.960849  35.248990
# ...                        ...        ...        ...       ...        ...
# range_Valence          21263.0   2.041010   1.242345  0.000000   1.000000
# wtd_range_Valence      21263.0   1.483007   0.978176  0.000000   0.921454
# std_Valence            21263.0   0.839342   0.484676  0.000000   0.451754
# wtd_std_Valence        21263.0   0.673987   0.455580  0.000000   0.306892
# critical_temp          21263.0  34.421219  34.254362  0.000210   5.365000
#
#                              50%         75%       max
# number_of_elements      4.000000    5.000000    9.0000
# mean_atomic_mass       84.922750  100.404410  208.9804
# wtd_mean_atomic_mass   60.696571   86.103540  208.9804
# gmean_atomic_mass      66.361592   78.116681  208.9804
# wtd_gmean_atomic_mass  39.918385   73.113234  208.9804
# ...                          ...         ...       ...
# range_Valence           2.000000    3.000000    6.0000
# wtd_range_Valence       1.063077    1.918400    6.9922
# std_Valence             0.800000    1.200000    3.0000
# wtd_std_Valence         0.500000    1.020436    3.0000
# critical_temp          20.000000   63.000000  185.0000
#
# [82 rows x 8 columns]

# %% [markdown]
# #### Which columns could be categorical ?

# %%
plot_categorical(df)

# %% [markdown]
# ### Dataset Cleaning

# %% [markdown]
# #### Duplicate rows:

# %%
duplicates(df)
# Out:
# Number of rows before removing: 21263
# Number of duplicate rows: 66
# Number of rows after removing: 21197
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                       4         88.944468             57.862692
# 1                       5         92.729214             58.518416
# 2                       4         88.944468             57.885242
# 3                       4         88.944468             57.873967
# 4                       4         88.944468             57.840143
# ...                   ...               ...                   ...
# 21258                   4        106.957877             53.095769
# 21259                   5         92.266740             49.021367
# 21260                   2         99.663190             95.609104
# 21261                   2         99.663190             97.095602
# 21262                   3         87.468333             86.858500
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0              66.361592              36.116612             1.181795
# 1              73.132787              36.396602             1.449309
# 2              66.361592              36.122509             1.181795
# 3              66.361592              36.119560             1.181795
# 4              66.361592              36.110716             1.181795
# ...                  ...                    ...                  ...
# 21258          82.515384              43.135565             1.177145
# 21259          64.812662              32.867748             1.323287
# 21260          99.433882              95.464320             0.690847
# 21261          99.433882              96.901083             0.690847
# 21262          82.555758              80.458722             1.041270
#
#        wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                     1.062396          122.90607              31.794921
# 1                     1.057755          122.90607              36.161939
# 2                     0.975980          122.90607              35.741099
# 3                     1.022291          122.90607              33.768010
# 4                     1.129224          122.90607              27.848743
# ...                        ...                ...                    ...
# 21258                 1.254119          146.88130              15.504479
# 21259                 1.571630          188.38390               7.353333
# 21260                 0.530198           13.51362              53.041104
# 21261                 0.640883           13.51362              31.115202
# 21262                 0.895229           71.75500              43.144000
#
#        std_atomic_mass  ...  wtd_mean_Valence  gmean_Valence  \
# 0            51.968828  ...          2.257143       2.213364
# 1            47.094633  ...          2.257143       1.888175
# 2            51.968828  ...          2.271429       2.213364
# 3            51.968828  ...          2.264286       2.213364
# 4            51.968828  ...          2.242857       2.213364
# ...                ...  ...               ...            ...
# 21258        65.764081  ...          3.555556       3.223710
# 21259        69.232655  ...          2.047619       2.168944
# 21260         6.756810  ...          4.800000       4.472136
# 21261         6.756810  ...          4.690000       4.472136
# 21262        29.905282  ...          4.500000       4.762203
#
#        wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0               2.219783         1.368922             1.066221              1
# 1               2.210679         1.557113             1.047221              2
# 2               2.232679         1.368922             1.029175              1
# 3               2.226222         1.368922             1.048834              1
# 4               2.206963         1.368922             1.096052              1
# ...                  ...              ...                  ...            ...
# 21258           3.519911         1.377820             0.913658              1
# 21259           2.038991         1.594167             1.337246              1
# 21260           4.781762         0.686962             0.450561              1
# 21261           4.665819         0.686962             0.577601              1
# 21262           4.242641         1.054920             0.970116              3
#
#        wtd_range_Valence  std_Valence  wtd_std_Valence  critical_temp
# 0               1.085714     0.433013         0.437059          29.00
# 1               1.128571     0.632456         0.468606          26.00
# 2               1.114286     0.433013         0.444697          19.00
# 3               1.100000     0.433013         0.440952          22.00
# 4               1.057143     0.433013         0.428809          23.00
# ...                  ...          ...              ...            ...
# 21258           2.168889     0.433013         0.496904           2.44
# 21259           0.904762     0.400000         0.212959         122.10
# 21260           3.200000     0.500000         0.400000           1.98
# 21261           2.210000     0.500000         0.462493           1.84
# 21262           1.800000     1.414214         1.500000          12.80
#
# [21197 rows x 82 columns]

# %% [markdown]
# #### Drop user's columns:

# %%
print('user_drop_cols = ', user_drop_cols)
# Out:
# user_drop_cols =  []

# %%
df = df.drop(user_drop_cols, axis=1)

# %% [markdown]
# #### Drop NaN:

# %%
df, drop_cols = drop_na(df, threshold_NaN)
# Out:
# No need to drop columns.

# %% [markdown]
# Final set of dropped columns

# %%
dropped_cols = np.unique(np.concatenate((drop_cols, user_drop_cols)))

# %%
display(dropped_cols)
# Out:
# array([], dtype=float64)

# %% [markdown]
# #### Encoding data:

# %%
df, encoded_cols = encoding(df, threshold_cat)
# Out:
# Encoding numeric column: number_of_elements
# Encoding numeric column: mean_atomic_mass
# Encoding numeric column: wtd_mean_atomic_mass
# Encoding numeric column: gmean_atomic_mass
# Encoding numeric column: wtd_gmean_atomic_mass
# Encoding numeric column: entropy_atomic_mass
# Encoding numeric column: wtd_entropy_atomic_mass
# Encoding numeric column: range_atomic_mass
# Encoding numeric column: wtd_range_atomic_mass
# Encoding numeric column: std_atomic_mass
# Encoding numeric column: wtd_std_atomic_mass
# Encoding numeric column: mean_fie
# Encoding numeric column: wtd_mean_fie
# Encoding numeric column: gmean_fie
# Encoding numeric column: wtd_gmean_fie
# Encoding numeric column: entropy_fie
# Encoding numeric column: wtd_entropy_fie
# Encoding numeric column: range_fie
# Encoding numeric column: wtd_range_fie
# Encoding numeric column: std_fie
# Encoding numeric column: wtd_std_fie
# Encoding numeric column: mean_atomic_radius
# Encoding numeric column: wtd_mean_atomic_radius
# Encoding numeric column: gmean_atomic_radius
# Encoding numeric column: wtd_gmean_atomic_radius
# Encoding numeric column: entropy_atomic_radius
# Encoding numeric column: wtd_entropy_atomic_radius
# Encoding numeric column: range_atomic_radius
# Encoding numeric column: wtd_range_atomic_radius
# Encoding numeric column: std_atomic_radius
# Encoding numeric column: wtd_std_atomic_radius
# Encoding numeric column: mean_Density
# Encoding numeric column: wtd_mean_Density
# Encoding numeric column: gmean_Density
# Encoding numeric column: wtd_gmean_Density
# Encoding numeric column: entropy_Density
# Encoding numeric column: wtd_entropy_Density
# Encoding numeric column: range_Density
# Encoding numeric column: wtd_range_Density
# Encoding numeric column: std_Density
# Encoding numeric column: wtd_std_Density
# Encoding numeric column: mean_ElectronAffinity
# Encoding numeric column: wtd_mean_ElectronAffinity
# Encoding numeric column: gmean_ElectronAffinity
# Encoding numeric column: wtd_gmean_ElectronAffinity
# Encoding numeric column: entropy_ElectronAffinity
# Encoding numeric column: wtd_entropy_ElectronAffinity
# Encoding numeric column: range_ElectronAffinity
# Encoding numeric column: wtd_range_ElectronAffinity
# Encoding numeric column: std_ElectronAffinity
# Encoding numeric column: wtd_std_ElectronAffinity
# Encoding numeric column: mean_FusionHeat
# Encoding numeric column: wtd_mean_FusionHeat
# Encoding numeric column: gmean_FusionHeat
# Encoding numeric column: wtd_gmean_FusionHeat
# Encoding numeric column: entropy_FusionHeat
# Encoding numeric column: wtd_entropy_FusionHeat
# Encoding numeric column: range_FusionHeat
# Encoding numeric column: wtd_range_FusionHeat
# Encoding numeric column: std_FusionHeat
# Encoding numeric column: wtd_std_FusionHeat
# Encoding numeric column: mean_ThermalConductivity
# Encoding numeric column: wtd_mean_ThermalConductivity
# Encoding numeric column: gmean_ThermalConductivity
# Encoding numeric column: wtd_gmean_ThermalConductivity
# Encoding numeric column: entropy_ThermalConductivity
# Encoding numeric column: wtd_entropy_ThermalConductivity
# Encoding numeric column: range_ThermalConductivity
# Encoding numeric column: wtd_range_ThermalConductivity
# Encoding numeric column: std_ThermalConductivity
# Encoding numeric column: wtd_std_ThermalConductivity
# Encoding numeric column: mean_Valence
# Encoding numeric column: wtd_mean_Valence
# Encoding numeric column: gmean_Valence
# Encoding numeric column: wtd_gmean_Valence
# Encoding numeric column: entropy_Valence
# Encoding numeric column: wtd_entropy_Valence
# Encoding numeric column: range_Valence
# Encoding numeric column: wtd_range_Valence
# Encoding numeric column: std_Valence
# Encoding numeric column: wtd_std_Valence
# Encoding numeric column: critical_temp

# %% [markdown]
# #### Imputing NaN using IterativeImputer

# %%
visualizer = MissingValuesBar(features=df.select_dtypes(include=np.number).columns.tolist())
visualizer.fit(df.select_dtypes(include=np.number))
visualizer.show();
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ##### Imputation

# %%
df = imputation(df)
# Out:
# No need to impute data.

# %% [markdown]
# #### Data compression:

# %%
df = downcast_dtypes(df)
# Out:
# Memory usage of dataframe is 13.30MB
# Memory usage after optimization is: 3.33MB
# Decreased by 75.0%

# %% [markdown]
# ##### Dataframe structure after compression

# %%
plot_dataframe_structure(df)

# %% [markdown]
# #### Outliers:

# %%
df = outliers(df, threshold_Z)
# Out:
# Using Z_score,  4836  rows will be suppressed.

# %% [markdown]
# #### Splitting dataframe in features and targets

# %%
y = df[target_col]

# %%
X = df.drop(target_col, axis=1)

# %% [markdown]
# ### Plottings

# %% [markdown]
# #### Ranking

# %% [markdown]
# ##### Ranking 1D

# %%
rank1d(df);

# %% [markdown]
# ##### Ranking 2D

# %% [markdown]
# ###### Ranking 2D according to Pearson

# %%
rank2d(df, algorithm='pearson');

# %% [markdown]
# ###### Ranking 2D based on covariance

# %%
rank2d(df, algorithm='covariance');

# %% [markdown]
# ###### Ranking 2D according to Spearman

# %%
rank2d(df, algorithm='spearman');

# %% [markdown]
# ###### Ranking 2D according to Kendalltau

# %%
rank2d(df, algorithm='kendalltau');

# %% [markdown]
# #### Correlation

# %% [markdown]
# ##### Correlation with Yellow Bricks

# %%
feature_correlation(X, y);

# %%
feature_correlation(X, y, method='mutual_info-regression');

# %% [markdown]
# #### Feature importance (a priori)

# %% [markdown]
# ##### According to decision tree

# %%
feature_importances(DecisionTreeRegressor(), X, y);

# %% [markdown]
# ##### According to elasticnet regression

# %%
feature_importances(ElasticNet(alpha=0.01, l1_ratio=0.5), X, y);

# %% [markdown]
# ## Splittings

# %%
df = df_copy

# %% [markdown]
# #### Splitting dataframe in features and targets

# %%
y = df[target_col]

# %%
X = df.drop(target_col, axis=1)

# %% [markdown]
# ##### Dimensions

# %%
d_F=len(X.columns.tolist())

# %%
d_T=len(y.unique())

# %% [markdown]
# ##### Splitting data in train and test sets

# %%
X_train, X_test, y_train, y_test = split(X, y, test_size=0.33, stratify=None)

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Model building

# %% [markdown]
# #### Pipeline building

# %% [markdown]
# ##### Select the categorical and numerical columns

# %%
cat_selector = make_column_selector(dtype_include=object)

# %%
num_selector = make_column_selector(dtype_include=np.number)

# %% [markdown]
# ##### For models based on tree

# %%
cat_tree_processor = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

# %%
num_tree_processor = SimpleImputer(strategy='mean', add_indicator=True)

# %%
tree_preprocessor = make_column_transformer((num_tree_processor, num_selector), (cat_tree_processor, cat_selector))

# %% [markdown]
# ##### For models not based on tree

# %%
cat_ntree_processor = OneHotEncoder(handle_unknown='ignore')

# %%
num_ntree_processor = make_pipeline(StandardScaler(), SimpleImputer(strategy='mean', add_indicator=True))

# %%
ntree_preprocessor = make_column_transformer((num_ntree_processor, num_selector), (cat_ntree_processor, cat_selector))

# %% [markdown]
# ##### Keras neural network definition

# %%
def K_Regre(): 
    keras.backend.clear_session()
#   neural network architecture: start  
    model = Sequential() 
    model.add(Dense(d_F + 1 + 2, input_dim=d_F, activation='relu')) 
    model.add(BatchNormalization()) 
#    model.add(LayerNormalization()) 
#   model.add(Dense(d_F + 1 + 2, activation='relu')) 
    model.add(Dense(1)) 
    model.compile(loss='mean_squared_error', optimizer='adam') 
#   neural network architecture: end   
    return model  
#   Keras training parameters: epoch and batch_size 
K_R = KerasRegressor(build_fn=K_Regre, epochs=1000, batch_size=64, verbose=0) 
K_R._estimator_type = 'regressor'

# %% [markdown]
# ##### Level-0 models

# %%
level_0 = [ 
          ('SGDR', make_pipeline(ntree_preprocessor, SGDRegressor(loss='squared_loss'))), 
          ('ELNE', make_pipeline(ntree_preprocessor, ElasticNet(alpha=0.01, l1_ratio=0.5))), 
          ('SVRL', make_pipeline(ntree_preprocessor, SVR(kernel='linear'))), 
          ('SVRP', make_pipeline(ntree_preprocessor, SVR(kernel='poly'))), 
          ('SVRG', make_pipeline(ntree_preprocessor, SVR(kernel='rbf'))), 
          ('XGBR', make_pipeline(tree_preprocessor, XGBRegressor(max_depth=5, n_estimators=20, verbosity=0))), 
          ]

# %% [markdown]
# ##### Level-1 model

# %%
level_1 = MLPRegressor()

# %% [markdown]
# ##### Stacking for regression

# %%
model = StackingRegressor(level_0, final_estimator=level_1)

# %% [markdown]
# ### Model fitting

# %%
# %%time
set_config(display='diagram') 
model.fit(X_train, y_train)
# Out:
# CPU times: user 7min 38s, sys: 31.8 s, total: 8min 10s
# Wall time: 6min 33s
# StackingRegressor(estimators=[('SGDR',
#                                Pipeline(steps=[('columntransformer',
#                                                 ColumnTransformer(transformers=[('pipeline',
#                                                                                  Pipeline(steps=[('standardscaler',
#                                                                                                   StandardScaler()),
#                                                                                                  ('simpleimputer',
#                                                                                                   SimpleImputer(add_indicator=True))]),
#                                                                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f9cdcb60310>),
#                                                                                 ('onehotencoder',
#                                                                                  OneHotEncoder(handle_unkno...
#                                                              interaction_constraints=None,
#                                                              learning_rate=None,
#                                                              max_delta_step=None,
#                                                              max_depth=5,
#                                                              min_child_weight=None,
#                                                              missing=nan,
#                                                              monotone_constraints=None,
#                                                              n_estimators=20,
#                                                              n_jobs=None,
#                                                              num_parallel_tree=None,
#                                                              random_state=None,
#                                                              reg_alpha=None,
#                                                              reg_lambda=None,
#                                                              scale_pos_weight=None,
#                                                              subsample=None,
#                                                              tree_method=None,
#                                                              validate_parameters=None,
#                                                              verbosity=0))]))],
#                   final_estimator=MLPRegressor())

# %% [markdown]
# ### Model evaluation

# %% [markdown]
# #### Model scoring

# %%
score_stacking_r(model, X_train, y_train, X_test, y_test)
# Out:
# array([['SGDR', 0.668796320728458, 0.6614643157556643],
#        ['ELNE', 0.6064974958599936, 0.5955866085202569],
#        ['SVRL', 0.6238104168937743, 0.6134995245029038],
#        ['SVRP', 0.24197476994044265, 0.19726928734285887],
#        ['SVRG', 0.707898978427514, 0.7038960685025194],
#        ['XGBR', 0.8997506069518973, 0.8679454086558244],
#        ['Stack', 0.9074646162694042, 0.8748418942093386]], dtype=object)

# %% [markdown]
# #### Residuals plot

# %%
residuals_plot(model, X_train, y_train, X_test, y_test);

# %% [markdown]
# #### Prediction error

# %%
prediction_error(model, X_train, y_train, X_test, y_test);
